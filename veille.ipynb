# %% [markdown]
# # Veille - Axel

# %% [markdown]
# E. La classification supervisée

# %% [markdown]
# F. La classification non supervisée

# %% [markdown]
# G. La régression

# %% [markdown]
# H. La validation croisée
